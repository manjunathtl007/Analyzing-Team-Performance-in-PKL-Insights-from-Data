# %%
import pandas as pd

# %%
df = pd.read_csv('D:\\final_dataset_pkla.csv')
#please import the file wrt the name of the csv file
# Out:
#      a                     b               c                    d a.1  \
# 0    #                  Name  Matches Played  Total Points Scored   #
# 1    4     Dabang Delhi K.C.             173                 5679   1
# 2    5         Puneri Paltan             175                 5666   6
# 3    8         Telugu Titans             170                 5437   4
# 4    7       Bengal Warriors             173                 5534   5
# 5    2       Bengaluru Bulls             178                 6021   3
# 6    3               U Mumba             175                 5720   7
# 7    1         Patna Pirates             180                 6257   2
# 8    6  Jaipur Pink Panthers             172                 5614   8
# 9   12       Tamil Thalaivas             112                 3581  11
# 10   9          U.P. Yoddhas             118                 4063   9
# 11  11      Haryana Steelers             112                 3762  10
# ...

# %%
df.drop(['b.1', 'b.2', 'b.3', 'b.3', 'b.4', 'b.5', 'b.6', 'b.7', 'b.8', 'b.9', 'b.10', 'b.11', 'b.12', 'b.13'], axis = 1, inplace=True)

# %%
df.drop(['c.1', 'c.2', 'c.3', 'c.3', 'c.4', 'c.5', 'c.6', 'c.7', 'c.8', 'c.9', 'c.10', 'c.11', 'c.12', 'c.13'], axis = 1, inplace=True)

# %%
df
# Out:
#      a                     b               c                    d a.1  \
# 0    #                  Name  Matches Played  Total Points Scored   #
# 1    4     Dabang Delhi K.C.             173                 5679   1
# 2    5         Puneri Paltan             173                 5598   6
# 3    8         Telugu Titans             170                 5437   4
# 4    6       Bengal Warriors             173                 5534   5
# 5    2       Bengaluru Bulls             177                 5992   3
# 6    3               U Mumba             175                 5720   7
# 7    1         Patna Pirates             180                 6257   2
# 8    7  Jaipur Pink Panthers             170                 5532   8
# 9   12       Tamil Thalaivas             111                 3544  11
# 10   9          U.P. Yoddhas             118                 4063   9
# 11  11      Haryana Steelers             112                 3762  10
# ...

# %%
df.drop(['a.1', 'a.2', 'a.3', 'a.3', 'a.4', 'a.5', 'a.6', 'a.7', 'a.8', 'a.9', 'a.10', 'a.11', 'a.12', 'a.13'], axis = 1, inplace=True)

# %%
df
# Out:
#      a                     b               c                    d  \
# 0    #                  Name  Matches Played  Total Points Scored
# 1    4     Dabang Delhi K.C.             173                 5679
# 2    5         Puneri Paltan             175                 5666
# 3    8         Telugu Titans             170                 5437
# 4    7       Bengal Warriors             173                 5534
# 5    2       Bengaluru Bulls             178                 6021
# 6    3               U Mumba             175                 5720
# 7    1         Patna Pirates             180                 6257
# 8    6  Jaipur Pink Panthers             172                 5614
# 9   12       Tamil Thalaivas             112                 3581
# 10   9          U.P. Yoddhas             118                 4063
# 11  11      Haryana Steelers             112                 3762
# 12  10        Gujarat Giants             116                 3907
#
# ...

# %%
df
# Out:
#      a                     b               c                    d  \
# 0    #                  Name  Matches Played  Total Points Scored
# 1    4     Dabang Delhi K.C.             173                 5679
# 2    5         Puneri Paltan             173                 5598
# 3    8         Telugu Titans             170                 5437
# 4    6       Bengal Warriors             173                 5534
# 5    2       Bengaluru Bulls             177                 5992
# 6    3               U Mumba             175                 5720
# 7    1         Patna Pirates             180                 6257
# 8    7  Jaipur Pink Panthers             170                 5532
# 9   12       Tamil Thalaivas             111                 3544
# 10   9          U.P. Yoddhas             118                 4063
# 11  11      Haryana Steelers             112                 3762
# 12  10        Gujarat Giants             116                 3907
#
# ...

# %%
df.to_csv('upd1.csv', index = False)

# %%
df1 = pd.read_csv("upd.csv", skiprows=1)

# %%
df1
# Out:
#      #                  Name  Matches Played  Total Points Scored  \
# 0    4     Dabang Delhi K.C.             173                 5679
# 1    5         Puneri Paltan             173                 5598
# 2    8         Telugu Titans             170                 5437
# 3    6       Bengal Warriors             173                 5534
# 4    2       Bengaluru Bulls             177                 5992
# 5    3               U Mumba             175                 5720
# 6    1         Patna Pirates             180                 6257
# 7    7  Jaipur Pink Panthers             170                 5532
# 8   12       Tamil Thalaivas             111                 3544
# 9    9          U.P. Yoddhas             118                 4063
# 10  11      Haryana Steelers             112                 3762
# 11  10        Gujarat Giants             116                 3907
#
#     Total Points Conceded  Avg. Points Scored  Successful Raids  Raid Points  \
# ...

# %%
df1.columns = df1.columns.str.replace(" ", "_")

# %%
df1
# Out:
#      #                  Name  Matches_Played  Total_Points_Scored  \
# 0    4     Dabang Delhi K.C.             173                 5679
# 1    5         Puneri Paltan             173                 5598
# 2    8         Telugu Titans             170                 5437
# 3    6       Bengal Warriors             173                 5534
# 4    2       Bengaluru Bulls             177                 5992
# 5    3               U Mumba             175                 5720
# 6    1         Patna Pirates             180                 6257
# 7    7  Jaipur Pink Panthers             170                 5532
# 8   12       Tamil Thalaivas             111                 3544
# 9    9          U.P. Yoddhas             118                 4063
# 10  11      Haryana Steelers             112                 3762
# 11  10        Gujarat Giants             116                 3907
#
#     Total_Points_Conceded  Avg._Points_Scored  Successful_Raids  Raid_Points  \
# ...

# %%
df1 = df1.rename(columns={"#": "Position"})

# %%
df1
# Out:
#     Position                  Name  Matches_Played  Total_Points_Scored  \
# 0          4     Dabang Delhi K.C.             173                 5679
# 1          5         Puneri Paltan             173                 5598
# 2          8         Telugu Titans             170                 5437
# 3          6       Bengal Warriors             173                 5534
# 4          2       Bengaluru Bulls             177                 5992
# 5          3               U Mumba             175                 5720
# 6          1         Patna Pirates             180                 6257
# 7          7  Jaipur Pink Panthers             170                 5532
# 8         12       Tamil Thalaivas             111                 3544
# 9          9          U.P. Yoddhas             118                 4063
# 10        11      Haryana Steelers             112                 3762
# 11        10        Gujarat Giants             116                 3907
#
# ...

# %%
df1.to_csv('dppkl1.csv', index = False)

# %%
df2 = pd.read_csv('D:\\final_dataset_pklam.csv')

# %%
df2.drop(['Team'], axis = 1, inplace = True)

# %%
df2
# Out:
#     Position                  Name  Matches_Played  Total_Points_Scored  \
# 0          1         Patna Pirates             180                 6257
# 1          2       Bengaluru Bulls             177                 5992
# 2          3               U Mumba             175                 5720
# 3          4     Dabang Delhi K.C.             173                 5679
# 4          5         Puneri Paltan             173                 5598
# 5          6       Bengal Warriors             173                 5534
# 6          7  Jaipur Pink Panthers             170                 5532
# 7          8         Telugu Titans             170                 5437
# 8          9          U.P. Yoddhas             118                 4063
# 9         10        Gujarat Giants             116                 3907
# 10        11      Haryana Steelers             112                 3762
# 11        12       Tamil Thalaivas             111                 3544
#
# ...

# %%
df2[['Won%', 'Loss%', 'Draw%']] = df2[['Won%', 'Loss%', 'Draw%']].replace('%', '', regex=True)

# %%
df2
# Out:
#     Position                  Name  Matches_Played  Total_Points_Scored  \
# 0          1         Patna Pirates             180                 6257
# 1          2       Bengaluru Bulls             177                 5992
# 2          3               U Mumba             175                 5720
# 3          4     Dabang Delhi K.C.             173                 5679
# 4          5         Puneri Paltan             173                 5598
# 5          6       Bengal Warriors             173                 5534
# 6          7  Jaipur Pink Panthers             170                 5532
# 7          8         Telugu Titans             170                 5437
# 8          9          U.P. Yoddhas             118                 4063
# 9         10        Gujarat Giants             116                 3907
# 10        11      Haryana Steelers             112                 3762
# 11        12       Tamil Thalaivas             111                 3544
#
# ...

# %%
df2.to_csv('onemore1.csv', index = False)
